# %%
import sys
import jax
import jax.numpy as jnp
import equinox as eqx
from pathlib import Path
from importlib import reload

src = str(Path('../src').resolve())
if src not in sys.path:
    sys.path.append(src)

import models
reload(models)

cfg = {'model': 'fusiontransformer',
       'model_args':{
           'daily_in_size': 8,
           'irregular_in_size': 12,
           'static_in_size': 38,
           'seq_length': 30,
           'hidden_size': 64,
           'intermediate_size': 64,
           'num_layers': 3,
           'num_heads': 3,
           'out_size': 2,
           'dropout': 0.1,
           'seed': 0
           }
      }
           
model = models.make(cfg)

print('success!')
# Out:
# success!

# %%
key = jax.random.PRNGKey(0)
keys = jax.random.split(key,batch_size)

jax.vmap(model)(data, days, static, masks, keys)
# Out:
# era5: (32,)
# landsat: (32,)
# (64,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[205], line 4
#       1 key = jax.random.PRNGKey(0)
#       2 keys = jax.random.split(key,batch_size)
# ----> 4 jax.vmap(model)(data, days, static, masks, keys)
#
#     [... skipping hidden 3 frame]
#
# Cell In[204], line 275, in HydroTransformer.__call__(self, data, days, static, masks, key)
#     266 def __call__(self,
#     267              data: Dict[str, jnp.ndarray],  # Dict of (seq_len, features) arrays
#     268              days: Dict[str, jnp.ndarray],  # Dict of (seq_len,) arrays
#    (...)
#     273
#     274     # Encode input data
# --> 275     encoded = self.encoder(data, days, static, masks, key)
#     277     # Learned pooling of encoded data
#     278     weights = jax.nn.softmax(self.pooler(encoded), axis=0)
#
# Cell In[204], line 234, in HierarchicalEncoder.__call__(self, data, days, static, masks, key)
#     232 cross_keys = jax.random.split(keys[2], len(self.cross_stream_layers))
#     233 for layer, layer_key in zip(self.cross_stream_layers, cross_keys):
# --> 234     combined = layer(combined, static_embed, combined_mask, layer_key)
#     236 return combined
#
# Cell In[204], line 152, in TransformerLayer.__call__(self, x, static, mask, key)
#     144 def __call__(self,
#     145              x: jnp.ndarray,  # Shape: (seq_len, d_model)
#     146              static: jnp.ndarray,  # Shape: (d_model,)
#     147              mask: Optional[jnp.ndarray] = None,
#     148              key: Optional[jax.random.PRNGKey] = None
#     149              ) -> jnp.ndarray:  # Shape: (seq_len, d_model)
#     150     attn_key, ff_key = jax.random.split(key) if key is not None else (None, None)
# --> 152     x = x + self.attention(self.ln1(x), self.ln1(x), self.ln1(x), static, mask, attn_key)
#     154     return x + jax.vmap(self.ff_block)(self.ln2(x))
#
#     [... skipping hidden 3 frame]
#
# File ~/.conda/envs/tss-ml/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File ~/.conda/envs/tss-ml/lib/python3.10/site-packages/equinox/nn/_normalisation.py:130, in LayerNorm.__call__(self, x, state, key)
#     113 """**Arguments:**
#     114
#     115 - `x`: A JAX array, with the same shape as the `shape` passed to `__init__`.
#    (...)
#     127 returned.
#     128 """
#     129 if x.shape != self.shape:
# --> 130     raise ValueError(
#     131         "`LayerNorm(shape)(x)` must satisfy the invariant `shape == x.shape`"
#     132         f"Received `shape={self.shape} and `x.shape={x.shape}`. You might need "
#     133         "to replace `layer_norm(x)` with `jax.vmap(layer_norm)(x)`.\n"
#     134         "\n"
#     135         "If this is a new error for you, it might be because this became "
#     136         "stricter in Equinox v0.11.0. Previously all that was required is that "
#     137         "`x.shape` ended with `shape`. However, this turned out to be a "
#     138         "frequent source of bugs, so we made the check stricter!"
#     139     )
#     140 mean = jnp.mean(x, keepdims=True)
#     141 variance = jnp.var(x, keepdims=True)
#
# ValueError: `LayerNorm(shape)(x)` must satisfy the invariant `shape == x.shape`Received `shape=(32,) and `x.shape=()`. You might need to replace `layer_norm(x)` with `jax.vmap(layer_norm)(x)`.
#
# If this is a new error for you, it might be because this became stricter in Equinox v0.11.0. Previously all that was required is that `x.shape` ended with `shape`. However, this turned out to be a frequent source of bugs, so we made the check stricter!

# %%
model.encoder.cross_stream_layers

# %%
batch_size = 8
seq_len = 40

data = {
    "era5": jax.random.normal(data_key, (batch_size, seq_len, dynamic_sizes["era5"])),
    "landsat": jax.random.normal(data_key, (batch_size, seq_len, dynamic_sizes["landsat"]))
}
days = {
    "era5": jnp.tile(jnp.arange(seq_len),[batch_size,1]),
    "landsat": jnp.tile(jax.random.randint(data_key, (seq_len,), 0, 365),[batch_size,1])
}
static = jax.random.normal(data_key, (batch_size, static_size))
masks = {
    "era5": jnp.ones((batch_size, seq_len), dtype=bool),
    "landsat": jax.random.bernoulli(data_key, 0.8, (batch_size, seq_len))
}
targets = jax.random.normal(data_key, (batch_size, seq_len, output_size))

# %%
model.encoder.cross_stream_layers
# Out:
# [TransformerLayer(
#    attention=ModulatedAttention(
#      mha=MultiheadAttention(
#        query_proj=Linear(
#          weight=f32[60,64],
#          bias=None,
#          in_features=64,
#          out_features=60,
#          use_bias=False
#        ),
#        key_proj=Linear(
#          weight=f32[60,64],
#          bias=None,
#          in_features=64,
#          out_features=60,
#          use_bias=False
#        ),
#        value_proj=Linear(
#          weight=f32[60,64],
#          bias=None,
#          in_features=64,
#          out_features=60,
#          use_bias=False
#        ),
#        output_proj=Linear(
#          weight=f32[64,60],
#          bias=None,
#          in_features=60,
#          out_features=64,
#          use_bias=False
#        ),
#        dropout=Dropout(p=0.1, inference=False),
#        num_heads=6,
#        query_size=64,
#        key_size=64,
#        value_size=64,
#        output_size=64,
#        qk_size=10,
#        vo_size=10,
#        use_query_bias=False,
#        use_key_bias=False,
#        use_value_bias=False,
#        use_output_bias=False
#      ),
#      static_proj=Linear(
#        weight=f32[64,64],
#        bias=f32[64],
#        in_features=64,
#        out_features=64,
#        use_bias=True
#      )
#    ),
#    ff_block=MLP(
#      layers=(
#        Linear(
#          weight=f32[64,64],
#          bias=f32[64],
#          in_features=64,
#          out_features=64,
#          use_bias=True
#        ),
#        Linear(
#          weight=f32[64,64],
#          bias=f32[64],
#          in_features=64,
#          out_features=64,
#          use_bias=True
#        ),
#        Linear(
#          weight=f32[128,64],
#          bias=f32[128],
#          in_features=64,
#          out_features=128,
#          use_bias=True
#        )
#      ),
#      activation=<function gelu>,
#      final_activation=<function <lambda>>,
#      use_bias=True,
#      use_final_bias=True,
#      in_size=64,
#      out_size=128,
#      width_size=64,
#      depth=2
#    ),
#    ln1=LayerNorm(
#      shape=(64,),
#      eps=1e-05,
#      use_weight=True,
#      use_bias=True,
#      weight=f32[64],
#      bias=f32[64]
#    ),
#    ln2=LayerNorm(
#      shape=(64,),
#      eps=1e-05,
#      use_weight=True,
#      use_bias=True,
#      weight=f32[64],
#      bias=f32[64]
#    )
#  ),
#  TransformerLayer(
#    attention=ModulatedAttention(
#      mha=MultiheadAttention(
#        query_proj=Linear(
#          weight=f32[60,64],
#          bias=None,
#          in_features=64,
#          out_features=60,
#          use_bias=False
#        ),
#        key_proj=Linear(
#          weight=f32[60,64],
#          bias=None,
#          in_features=64,
#          out_features=60,
#          use_bias=False
#        ),
#        value_proj=Linear(
#          weight=f32[60,64],
#          bias=None,
#          in_features=64,
#          out_features=60,
#          use_bias=False
#        ),
#        output_proj=Linear(
#          weight=f32[64,60],
#          bias=None,
#          in_features=60,
#          out_features=64,
#          use_bias=False
#        ),
#        dropout=Dropout(p=0.1, inference=False),
#        num_heads=6,
#        query_size=64,
#        key_size=64,
#        value_size=64,
#        output_size=64,
#        qk_size=10,
#        vo_size=10,
#        use_query_bias=False,
#        use_key_bias=False,
#        use_value_bias=False,
#        use_output_bias=False
#      ),
#      static_proj=Linear(
#        weight=f32[64,64],
#        bias=f32[64],
#        in_features=64,
#        out_features=64,
#        use_bias=True
#      )
#    ),
#    ff_block=MLP(
#      layers=(
#        Linear(
#          weight=f32[64,64],
#          bias=f32[64],
#          in_features=64,
#          out_features=64,
#          use_bias=True
#        ),
#        Linear(
#          weight=f32[64,64],
#          bias=f32[64],
#          in_features=64,
#          out_features=64,
#          use_bias=True
#        ),
#        Linear(
#          weight=f32[128,64],
#          bias=f32[128],
#          in_features=64,
#          out_features=128,
#          use_bias=True
#        )
#      ),
#      activation=<function gelu>,
#      final_activation=<function <lambda>>,
#      use_bias=True,
#      use_final_bias=True,
#      in_size=64,
#      out_size=128,
#      width_size=64,
#      depth=2
#    ),
#    ln1=LayerNorm(
#      shape=(64,),
#      eps=1e-05,
#      use_weight=True,
#      use_bias=True,
#      weight=f32[64],
#      bias=f32[64]
#    ),
#    ln2=LayerNorm(
#      shape=(64,),
#      eps=1e-05,
#      use_weight=True,
#      use_bias=True,
#      weight=f32[64],
#      bias=f32[64]
#    )
#  ),
#  TransformerLayer(
#    attention=ModulatedAttention(
#      mha=MultiheadAttention(
#        query_proj=Linear(
#          weight=f32[60,64],
#          bias=None,
#          in_features=64,
#          out_features=60,
#          use_bias=False
#        ),
#        key_proj=Linear(
#          weight=f32[60,64],
#          bias=None,
#          in_features=64,
#          out_features=60,
#          use_bias=False
#        ),
#        value_proj=Linear(
#          weight=f32[60,64],
#          bias=None,
#          in_features=64,
#          out_features=60,
#          use_bias=False
#        ),
#        output_proj=Linear(
#          weight=f32[64,60],
#          bias=None,
#          in_features=60,
#          out_features=64,
#          use_bias=False
#        ),
#        dropout=Dropout(p=0.1, inference=False),
#        num_heads=6,
#        query_size=64,
#        key_size=64,
#        value_size=64,
#        output_size=64,
#        qk_size=10,
#        vo_size=10,
#        use_query_bias=False,
#        use_key_bias=False,
#        use_value_bias=False,
#        use_output_bias=False
#      ),
#      static_proj=Linear(
#        weight=f32[64,64],
#        bias=f32[64],
#        in_features=64,
#        out_features=64,
#        use_bias=True
#      )
#    ),
#    ff_block=MLP(
#      layers=(
#        Linear(
#          weight=f32[64,64],
#          bias=f32[64],
#          in_features=64,
#          out_features=64,
#          use_bias=True
#        ),
#        Linear(
#          weight=f32[64,64],
#          bias=f32[64],
#          in_features=64,
#          out_features=64,
#          use_bias=True
#        ),
#        Linear(
#          weight=f32[128,64],
#          bias=f32[128],
#          in_features=64,
#          out_features=128,
#          use_bias=True
#        )
#      ),
#      activation=<function gelu>,
#      final_activation=<function <lambda>>,
#      use_bias=True,
#      use_final_bias=True,
#      in_size=64,
#      out_size=128,
#      width_size=64,
#      depth=2
#    ),
#    ln1=LayerNorm(
#      shape=(64,),
#      eps=1e-05,
#      use_weight=True,
#      use_bias=True,
#      weight=f32[64],
#      bias=f32[64]
#    ),
#    ln2=LayerNorm(
#      shape=(64,),
#      eps=1e-05,
#      use_weight=True,
#      use_bias=True,
#      weight=f32[64],
#      bias=f32[64]
#    )
#  )]
